# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
#Math course
student_mat = pd.read_csv('/content/student-mat.csv',delimiter=';')

# %%
#Math course in Gabriel Pereira
student_mat_gp = student_mat[student_mat['school']=='GP']
student_mat_gp.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student_mat_gp.describe()
# Out:
#              age        Medu        Fedu  traveltime   studytime    failures  \
# count  349.00000  349.000000  349.000000  349.000000  349.000000  349.000000
# mean    16.52149    2.802292    2.553009    1.386819    2.063037    0.318052
# std      1.21661    1.068566    1.080482    0.666910    0.851998    0.734409
# min     15.00000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.00000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     16.00000    3.000000    3.000000    1.000000    2.000000    0.000000
# 75%     17.00000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.00000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  349.000000  349.000000  349.000000  349.000000  349.000000  349.000000
# mean     3.959885    3.223496    3.111748    1.444126    2.260745    3.575931
# ...

# %%
student_mat_gp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349 entries, 0 to 348
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      349 non-null    object
#  1   sex         349 non-null    object
#  2   age         349 non-null    int64
#  3   address     349 non-null    object
#  4   famsize     349 non-null    object
#  5   Pstatus     349 non-null    object
#  6   Medu        349 non-null    int64
#  7   Fedu        349 non-null    int64
#  8   Mjob        349 non-null    object
#  9   Fjob        349 non-null    object
#  10  reason      349 non-null    object
#  11  guardian    349 non-null    object
#  12  traveltime  349 non-null    int64
#  13  studytime   349 non-null    int64
#  14  failures    349 non-null    int64
#  15  schoolsup   349 non-null    object
#  16  famsup      349 non-null    object
#  17  paid        349 non-null    object
#  18  activities  349 non-null    object
# ...

# %%
#Total and average grade for the three quarters
total = student_mat_gp.loc[:,['G1','G2','G3']].sum(axis=1)
student_mat_gp['Avg_G'] = total/3

student_mat_gp.head()
# Out:
# <ipython-input-6-98296b414ed1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_mat_gp['Avg_G'] = total/3
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3      Avg_G
# 0        3     4     1     1       3        6   5   6   6   5.666667
# ...

# %%
#Reshape DataFrame to a long format
student_mat_gp_l = student_mat_gp.melt(id_vars=['age','traveltime','studytime','failures','goout','Dalc','Walc','freetime','health','absences'],
                                       value_vars=['G1','G2','G3','Avg_G'],
                                       var_name='Period',
                                       value_name='Grade')
student_mat_gp_l.head()
# Out:
#    age  traveltime  studytime  failures  goout  Dalc  Walc  freetime  health  \
# 0   18           2          2         0      4     1     1         3       3
# 1   17           1          2         0      3     1     1         3       3
# 2   15           1          2         3      2     2     3         3       3
# 3   15           1          3         0      2     1     1         2       5
# 4   16           1          2         0      2     1     2         3       5
#
#    absences Period  Grade
# 0         6     G1    5.0
# 1         4     G1    5.0
# 2        10     G1    7.0
# 3         2     G1   15.0
# 4         4     G1    6.0

# %%
sns.distplot(student_mat_gp['G1'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness: %f" % student_mat_gp['G1'].skew())
print("Kurtosis: %f" % student_mat_gp['G1'].kurt())
# Out:
# Skewness: 0.219032
# Kurtosis: -0.711095

# %%
sns.distplot(student_mat_gp['G2'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness: %f" % student_mat_gp['G2'].skew())
print("Kurtosis: %f" % student_mat_gp['G2'].kurt())
# Out:
# Skewness: -0.494274
# Kurtosis: 0.759944

# %%
sns.distplot(student_mat_gp['G3'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness: %f" % student_mat_gp['G3'].skew())
print("Kurtosis: %f" % student_mat_gp['G3'].kurt())
# Out:
# Skewness: -0.748659
# Kurtosis: 0.387862

# %%
sns.distplot(student_mat_gp['Avg_G'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness: %f" % student_mat_gp['Avg_G'].skew())
print("Kurtosis: %f" % student_mat_gp['Avg_G'].kurt())
# Out:
# Skewness: -0.163525
# Kurtosis: -0.317996

# %%
schoolsup_dummies = pd.get_dummies(student_mat_gp['schoolsup'], prefix='schoolsup', drop_first=False)
famsup_dummies = pd.get_dummies(student_mat_gp['famsup'], prefix='famsup', drop_first=False)
paid_dummies = pd.get_dummies(student_mat_gp['paid'], prefix='paid', drop_first=False)
activities_dummies = pd.get_dummies(student_mat_gp['activities'], prefix='activities', drop_first=False)
nursery_dummies = pd.get_dummies(student_mat_gp['nursery'], prefix='nursery', drop_first=False)
higher_dummies = pd.get_dummies(student_mat_gp['higher'], prefix='higher', drop_first=False)
internet_dummies = pd.get_dummies(student_mat_gp['internet'], prefix='internet', drop_first=False)
romantic_dummies = pd.get_dummies(student_mat_gp['romantic'], prefix='romantic', drop_first=False)

# %%
schoolsup_dummies.head()
# Out:
#    schoolsup_no  schoolsup_yes
# 0             0              1
# 1             1              0
# 2             0              1
# 3             1              0
# 4             1              0
